# %% [markdown]
# Begin
# Collect Receipt
# Pack my Goods
# Head to the Exit
# Security Guard checks receipt
# Head to the Car
# Drive off
# Enter Home
# Unload Goods
# End
# ![Store Checkout Flowchart.png](attachment:7e649b6b-b53f-4e3d-ac09-67d3dae00709.png)

# %% [markdown]
# ![image.png](attachment:e1bfb5aa-f81a-4ad9-911c-38cedd8f0b06.png)

# %% [markdown]
# BEGIN
# INPUT Name 1
# INPUT Name 2
# INPUT Age 1
# INPUT Age 2
# COMPUTE temp = Name 1
# COMPUTE Name 1 = Name 2
# COMPUTE Name 2 = temp
# COMPUTE temp = Age 1
# COMPUTE Age 1 = Age 2
# COMPUTE AGE 2 = temp
# DISPLAY Name 1
# DISPLAY Name 2
# DiSPLAY Age 1
# DISPLAY Age 2
# END
