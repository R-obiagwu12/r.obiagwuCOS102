# %%
# Import pandas library
import pandas as pd

# Boys data
boys_names = ["Chinedu","Liam","Wale","Gbenga","Abiola","Kola","Kunle","George","Thomas","Wesley"]
boys_age = [19,16,18,17,20,19,16,18,17,19]
boys_height = [5.7,5.9,5.8,6.1,5.9,5.5,6.1,5.4,5.8,5.7]
boys_scores = [74,87,75,68,66,78,87,98,54,60]

# Girls data
girls_names = ["Evelyn","Jessica","Somto","Edith","Liza","Madonna","Waje","Tola","Aisha","Latifa"]
girls_age = [17,16,17,18,16,18,17,20,19,17]
girls_height = [5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5]
girls_scores = [80,85,70,60,76,66,87,95,50,49]

# Table formation
names = boys_names + girls_names
ages = boys_age + girls_age
heights = boys_height + girls_height
scores = boys_scores + girls_scores

# Create Table
data = {"Name": names,"Age": ages,"Height": heights,"Score": scores}

df = pd.DataFrame(data)

# Display table
print(df)
# Out:
#        Name  Age  Height  Score
# 0   Chinedu   19     5.7     74
# 1      Liam   16     5.9     87
# 2      Wale   18     5.8     75
# 3    Gbenga   17     6.1     68
# 4    Abiola   20     5.9     66
# 5      Kola   19     5.5     78
# 6     Kunle   16     6.1     87
# 7    George   18     5.4     98
# 8    Thomas   17     5.8     54
# 9    Wesley   19     5.7     60
# 10   Evelyn   17     5.5     80
# 11  Jessica   16     6.0     85
# 12    Somto   17     5.4     70
# 13    Edith   18     5.9     60
# 14     Liza   16     5.6     76
# 15  Madonna   18     5.5     66
# 16     Waje   17     6.1     87
# 17     Tola   20     6.0     95
# 18    Aisha   19     5.7     50
# 19   Latifa   17     5.5     49
