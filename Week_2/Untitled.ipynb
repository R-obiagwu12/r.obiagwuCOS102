# %%
import numpy as np

print("Choose the equation to solve")
print("1. Quadratic Equation")
print("2. Cubic Equation")
print("3. Quartic Equation")

choice = int(input("Enter your choice: "))

if choice == 1:
    print("Ax**2 + Bx + C")
    a = float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))

    discriminant = b**2 - 4*a*c

    root1 = (-b + discriminant**0.5) / (2*a)
    root2 = (-b - discriminant**0.5) / (2*a)

    print("Roots are:", root1, root2)

elif choice == 2:
    print("Ax**3 + Bx**2 + Cx + D")
    A = float(input("Enter A: "))
    B = float(input("Enter B: "))
    C = float(input("Enter C: "))
    D = float(input("Enter D: "))

    roots = np.roots([A, B, C, D])
    print("Roots are:", roots)

elif choice == 3:
    print("Ax**4 + Bx**3 + Cx**2 + Dx + E")
    a = float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))
    d = float(input("Enter d: "))
    e = float(input("Enter e: "))

    roots = np.roots([a, b, c, d, e])
    print("Roots are:", roots)

else:
    print("Invalid choice")
# Out:
# Choose the equation to solve
# 1. Quadratic Equation
# 2. Cubic Equation
# 3. Quartic Equation
# Enter your choice:  3
# Ax**4 + Bx**3 + Cx**2 + Dx + E
# Enter a:  5
# Enter b:  6
# Enter c:  7
# Enter d:  8
# Enter e:  9
# Roots are: [ 0.34095492+1.10521727j  0.34095492-1.10521727j -0.94095492+0.6783371j
#  -0.94095492-0.6783371j ]
